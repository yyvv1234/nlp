# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_selector as selector
from sklearn.preprocessing import FunctionTransformer

hotel_data = pd.read_csv("hotel.csv", low_memory=False)

# %%
hotel_data.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# 5                        27                          1
# 6                        27                          1
# 7                        27                          1
# 8                        27                          1
# 9                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
# 5                        0                     2       2  ...    No Deposit
# 6                        0                     2       2  ...    No Deposit
# 7                        0                     2       2  ...    No Deposit
# 8                        0                     3       2  ...    No Deposit
# 9                        0                     3       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type    adr  \
# 0    NaN     NaN                    0     Transient    0.0
# 1    NaN     NaN                    0     Transient    0.0
# 2    NaN     NaN                    0     Transient   75.0
# 3  304.0     NaN                    0     Transient   75.0
# 4  240.0     NaN                    0     Transient   98.0
# 5  240.0     NaN                    0     Transient   98.0
# 6    NaN     NaN                    0     Transient  107.0
# 7  303.0     NaN                    0     Transient  103.0
# 8  240.0     NaN                    0     Transient   82.0
# 9   15.0     NaN                    0     Transient  105.5
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
# 5                            0                          1           Check-Out
# 6                            0                          0           Check-Out
# 7                            0                          1           Check-Out
# 8                            0                          1            Canceled
# 9                            0                          0            Canceled
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
# 5              2015-07-03
# 6              2015-07-03
# 7              2015-07-03
# 8              2015-05-06
# 9              2015-04-22
#
# [10 rows x 32 columns]

# %%
hotel_data.shape
# Out:
# (119390, 32)

# %%
# Dropped this feature because we have already the date separated in other features 
hotel_data.drop('reservation_status_date', inplace=True, axis=1)
hotel_data.drop('reservation_status', inplace=True, axis=1)

# %%
# Convert "children" column to numeric, replacing non-numeric values with NaN
hotel_data['children'] = pd.to_numeric(hotel_data['children'], errors='coerce')

# Calculate the mean of the numeric values in the "children" column
mean_children = hotel_data['children'].mean()

# Replace "na" strings with the mean
hotel_data['children'].fillna(mean_children, inplace=True)
# Out:
# c:\Temp\ipykernel_11104\581495295.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hotel_data['children'].fillna(mean_children, inplace=True)

# %%
# check if it worked and there is no "na"
hotel_data['children'].unique()
# Out:
# array([ 0.       ,  1.       ,  2.       , 10.       ,  3.       ,
#         0.1038899])

# %%
hotel_data.fillna(0, inplace=True)

# %%
hotel_data.isna().any().any()
# Out:
# False

# %%
categorical_features = ['customer_type',
                       'deposit_type', 'assigned_room_type', 'reserved_room_type', 'distribution_channel',
                       'market_segment', 'country', 'meal', 'hotel', 'arrival_date_month']
for key in categorical_features:
    hotel_data[key] = hotel_data[key].astype(str)
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(dtype='int',drop='first'))
])

# %%
numeric_features = ['total_of_special_requests', 'required_car_parking_spaces', 'adr',
                   'days_in_waiting_list', 'booking_changes', 'previous_bookings_not_canceled',
                   'previous_cancellations', 'babies', 'children', 'adults', 'stays_in_week_nights',
                   'stays_in_weekend_nights', 'arrival_date_day_of_month', 'arrival_date_week_number',
                   'lead_time']
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

# %%
# scale, encode and skip columns with 1/0 values
preprocessor = ColumnTransformer(
    transformers=[
        ('encode', categorical_transformer, categorical_features),
        ('scale', numeric_transformer, numeric_features),
        ('skip', 'passthrough', ['is_repeated_guest', 'is_canceled'])
    ])

# %%
# Apply preprocessing to the dataset
processed_data = preprocessor.fit_transform(hotel_data)

# %%
# convert the processed data back to DF
hotel_data = pd.DataFrame.sparse.from_spmatrix(processed_data, columns=preprocessor.get_feature_names_out())
print(hotel_data[hotel_data.columns[1:]].corr()['skip__is_canceled'][:].to_string())
# Out:
# encode__customer_type_Transient           0.133084
# encode__customer_type_Transient-Party    -0.124135
# encode__deposit_type_Non Refund           0.481457
# encode__deposit_type_Refundable          -0.011312
# encode__assigned_room_type_B             -0.037610
# encode__assigned_room_type_C             -0.053877
# encode__assigned_room_type_D             -0.128036
# encode__assigned_room_type_E             -0.064794
# encode__assigned_room_type_F             -0.045978
# encode__assigned_room_type_G             -0.019864
# encode__assigned_room_type_H             -0.002869
# encode__assigned_room_type_I             -0.040784
# encode__assigned_room_type_K             -0.032813
# encode__assigned_room_type_L              0.003773
# encode__assigned_room_type_P              0.013071
# encode__reserved_room_type_B             -0.008306
# encode__reserved_room_type_C             -0.007337
# encode__reserved_room_type_D             -0.047702
# encode__reserved_room_type_E             -0.038634
# encode__reserved_room_type_F             -0.021766
# encode__reserved_room_type_G             -0.001672
# encode__reserved_room_type_H              0.005485
# encode__reserved_room_type_L             -0.000544
# encode__reserved_room_type_P              0.013071
# encode__distribution_channel_Direct      -0.151620
# encode__distribution_channel_GDS         -0.014891
# encode__distribution_channel_TA/TO        0.175944
# encode__distribution_channel_Undefined    0.005757
# encode__market_segment_Complementary     -0.039306
# encode__market_segment_Corporate         -0.081667
# encode__market_segment_Direct            -0.154390
# encode__market_segment_Groups             0.221859
# encode__market_segment_Offline TA/TO     -0.028472
# encode__market_segment_Online TA         -0.006288
# encode__market_segment_Undefined          0.005336
# encode__country_ABW                      -0.003139
# encode__country_AGO                       0.022369
# encode__country_AIA                      -0.002220
# encode__country_ALB                      -0.004230
# encode__country_AND                       0.005453
# encode__country_ARE                       0.020236
# encode__country_ARG                      -0.010361
# encode__country_ARM                      -0.002041
# encode__country_ASM                      -0.002220
# encode__country_ATA                      -0.003139
# encode__country_ATF                      -0.002220
# encode__country_AUS                      -0.014776
# encode__country_AUT                      -0.040321
# encode__country_AZE                       0.003929
# encode__country_BDI                      -0.002220
# encode__country_BEL                      -0.049217
# encode__country_BEN                       0.006535
# encode__country_BFA                      -0.002220
# encode__country_BGD                       0.007881
# encode__country_BGR                      -0.010924
# encode__country_BHR                       0.005757
# encode__country_BHS                      -0.002220
# encode__country_BIH                      -0.003018
# encode__country_BLR                      -0.000742
# encode__country_BOL                      -0.007020
# encode__country_BRA                       0.000795
# encode__country_BRB                      -0.004440
# encode__country_BWA                      -0.002220
# encode__country_CAF                      -0.004964
# encode__country_CHE                      -0.030889
# encode__country_CHL                      -0.006006
# encode__country_CHN                       0.017509
# encode__country_CIV                      -0.000544
# encode__country_CMR                      -0.007020
# encode__country_CN                       -0.037026
# encode__country_COL                      -0.002347
# encode__country_COM                      -0.003139
# encode__country_CPV                       0.003805
# encode__country_CRI                      -0.008302
# encode__country_CUB                      -0.006279
# encode__country_CYM                      -0.002220
# encode__country_CYP                      -0.006624
# encode__country_CZE                      -0.012081
# encode__country_DEU                      -0.107316
# encode__country_DJI                      -0.002220
# encode__country_DMA                      -0.002220
# encode__country_DNK                      -0.015007
# encode__country_DOM                       0.004508
# encode__country_DZA                      -0.010133
# encode__country_ECU                      -0.002308
# encode__country_EGY                      -0.000904
# encode__country_ESP                      -0.066981
# encode__country_EST                      -0.008387
# encode__country_ETH                      -0.000385
# encode__country_FIN                      -0.027427
# encode__country_FJI                       0.003773
# encode__country_FRA                      -0.118254
# encode__country_FRO                       0.005757
# encode__country_GAB                       0.001553
# encode__country_GBR                      -0.117106
# encode__country_GEO                       0.008754
# encode__country_GGY                       0.006535
# encode__country_GHA                       0.001553
# encode__country_GIB                       0.006120
# encode__country_GLP                       0.005336
# encode__country_GNB                      -0.004662
# encode__country_GRC                      -0.006579
# encode__country_GTM                      -0.004440
# encode__country_GUY                      -0.002220
# encode__country_HKG                       0.016982
# encode__country_HND                       0.003773
# encode__country_HRV                      -0.007220
# encode__country_HUN                      -0.003242
# encode__country_IDN                       0.011181
# encode__country_IMN                       0.005336
# encode__country_IND                      -0.010362
# encode__country_IRL                      -0.043759
# encode__country_IRN                      -0.005096
# encode__country_IRQ                      -0.008307
# encode__country_ISL                      -0.013588
# encode__country_ISR                      -0.018312
# encode__country_ITA                      -0.006151
# encode__country_JAM                      -0.005438
# encode__country_JEY                       0.010672
# encode__country_JOR                      -0.006250
# encode__country_JPN                      -0.019218
# encode__country_KAZ                      -0.002802
# encode__country_KEN                      -0.000544
# encode__country_KHM                       0.005336
# encode__country_KIR                      -0.002220
# encode__country_KNA                      -0.003139
# encode__country_KOR                       0.002982
# encode__country_KWT                       0.000110
# encode__country_LAO                      -0.003139
# encode__country_LBN                      -0.002673
# encode__country_LBY                      -0.006279
# encode__country_LCA                      -0.002220
# encode__country_LIE                      -0.000385
# encode__country_LKA                      -0.005873
# encode__country_LTU                      -0.015323
# encode__country_LUX                       0.000953
# encode__country_LVA                      -0.009193
# encode__country_MAC                       0.013595
# encode__country_MAR                       0.004869
# encode__country_MCO                      -0.001443
# encode__country_MDG                      -0.002220
# encode__country_MDV                       0.007881
# encode__country_MEX                      -0.013971
# encode__country_MKD                      -0.003230
# encode__country_MLI                      -0.002220
# encode__country_MLT                      -0.002356
# encode__country_MMR                      -0.002220
# encode__country_MNE                       0.000396
# encode__country_MOZ                      -0.004261
# encode__country_MRT                      -0.002220
# encode__country_MUS                      -0.003608
# encode__country_MWI                      -0.003139
# encode__country_MYS                      -0.008350
# encode__country_MYT                       0.005336
# encode__country_NAM                      -0.002220
# encode__country_NCL                      -0.002220
# encode__country_NGA                       0.008641
# encode__country_NIC                       0.003773
# encode__country_NLD                      -0.051720
# encode__country_NOR                      -0.010692
# encode__country_NPL                      -0.002220
# encode__country_NZL                      -0.014921
# encode__country_OMN                      -0.003768
# encode__country_PAK                       0.006110
# encode__country_PAN                      -0.006660
# encode__country_PER                      -0.005278
# encode__country_PHL                       0.009651
# encode__country_PLW                      -0.002220
# encode__country_POL                      -0.024889
# encode__country_PRI                      -0.004230
# encode__country_PRT                       0.336122
# encode__country_PRY                      -0.004440
# encode__country_PYF                      -0.002220
# encode__country_QAT                       0.008424
# encode__country_ROU                      -0.013753
# encode__country_RUS                       0.001170
# encode__country_RWA                      -0.003139
# encode__country_SAU                       0.013168
# encode__country_SDN                      -0.002220
# encode__country_SEN                       0.007093
# encode__country_SGP                       0.001491
# encode__country_SLE                      -0.002220
# encode__country_SLV                      -0.003139
# encode__country_SMR                      -0.002220
# encode__country_SRB                      -0.020529
# encode__country_STP                      -0.003139
# encode__country_SUR                      -0.004964
# encode__country_SVK                      -0.000057
# encode__country_SVN                      -0.004854
# encode__country_SWE                      -0.028647
# encode__country_SYC                       0.001098
# encode__country_SYR                      -0.003845
# encode__country_TGO                      -0.003139
# encode__country_THA                      -0.003008
# encode__country_TJK                       0.009322
# encode__country_TMP                      -0.000385
# encode__country_TUN                       0.004371
# encode__country_TUR                       0.003862
# encode__country_TWN                      -0.004106
# encode__country_TZA                       0.003077
# encode__country_UGA                      -0.003139
# encode__country_UKR                      -0.003772
# encode__country_UMI                       0.003773
# encode__country_URY                      -0.003023
# encode__country_USA                      -0.036411
# encode__country_UZB                       0.001553
# encode__country_VEN                       0.002785
# encode__country_VGB                       0.003773
# encode__country_VNM                      -0.002041
# encode__country_ZAF                       0.000916
# encode__country_ZMB                       0.001098
# encode__country_ZWE                       0.001553
# encode__meal_FB                           0.038828
# encode__meal_HB                          -0.019845
# encode__meal_SC                           0.001282
# encode__meal_Undefined                   -0.025896
# encode__hotel_Resort Hotel               -0.136531
# encode__arrival_date_month_August         0.005343
# encode__arrival_date_month_December      -0.010524
# encode__arrival_date_month_February      -0.020212
# encode__arrival_date_month_January       -0.031073
# encode__arrival_date_month_July           0.002938
# encode__arrival_date_month_June           0.029039
# encode__arrival_date_month_March         -0.030266
# encode__arrival_date_month_May            0.017989
# encode__arrival_date_month_November      -0.029544
# encode__arrival_date_month_October        0.006682
# encode__arrival_date_month_September      0.013693
# scale__total_of_special_requests         -0.234658
# scale__required_car_parking_spaces       -0.195498
# scale__adr                                0.047557
# scale__days_in_waiting_list               0.054186
# scale__booking_changes                   -0.144381
# scale__previous_bookings_not_canceled    -0.057358
# scale__previous_cancellations             0.110133
# scale__babies                            -0.032491
# scale__children                           0.005048
# scale__adults                             0.060017
# scale__stays_in_week_nights               0.024765
# scale__stays_in_weekend_nights           -0.001791
# scale__arrival_date_day_of_month         -0.006130
# scale__arrival_date_week_number           0.008148
# scale__lead_time                          0.293123
# skip__is_repeated_guest                  -0.084793
# skip__is_canceled                         1.000000

# %%
# split to features / label
y = hotel_data['skip__is_canceled']
X = hotel_data.drop('skip__is_canceled', axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (107451, 245) (11939, 245) (107451,) (11939,)

# %%
from sklearn.linear_model import LogisticRegression
import sys
np.set_printoptions(threshold=sys.maxsize)
# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=1000)

# fit the model with data
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

# %%
scores = cross_val_score(logreg, X, y, cv=5, scoring='accuracy')
print("Cross-Validation Scores:", scores)
print("Mean Accuracy:", scores.mean())
print("Standard Deviation:", scores.std())
# Out:
# Cross-Validation Scores: [0.71023536 0.72929056 0.7464193  0.71949074 0.74507915]
# Mean Accuracy: 0.7301030237038278
# Standard Deviation: 0.01413159397744032

# %%
from sklearn.metrics import classification_report
target_names = ['no_cancel', 'yes_cancel']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    no_cancel       0.83      0.91      0.87      7522
#   yes_cancel       0.82      0.67      0.74      4417
#
#     accuracy                           0.82     11939
#    macro avg       0.82      0.79      0.80     11939
# weighted avg       0.82      0.82      0.82     11939
